# %% [markdown]
# <a href="https://colab.research.google.com/github/POYYALASIVAPRASAD/feedforward/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
data = ['the glass of milk',
        'the glass of wine',
        'the cup of tea',
        'i am a bad boy',
        'understanding the meaning of words',
        'i love movies']

# %%
voc_size = 1000

# %%
onehot_rep = [one_hot(words,voc_size)for words in data]
onehot_rep
# Out:
# [[397, 418, 679, 2],
#  [397, 418, 679, 761],
#  [397, 279, 679, 183],
#  [332, 685, 315, 284, 45],
#  [642, 397, 430, 679, 586],
#  [332, 608, 140]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#import numpy as np

# %%
sent_length = 10
embedded_docs = pad_sequences(onehot_rep,padding='post',maxlen = sent_length)
embedded_docs
# Out:
# array([[397, 418, 679,   2,   0,   0,   0,   0,   0,   0],
#        [397, 418, 679, 761,   0,   0,   0,   0,   0,   0],
#        [397, 279, 679, 183,   0,   0,   0,   0,   0,   0],
#        [332, 685, 315, 284,  45,   0,   0,   0,   0,   0],
#        [642, 397, 430, 679, 586,   0,   0,   0,   0,   0],
#        [332, 608, 140,   0,   0,   0,   0,   0,   0,   0]], dtype=int32)

# %%
dim = 15

# %%
model = Sequential()
model.add(Embedding(voc_size,15,input_length = sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, 10, 15)            15000
#
# ...
# Total params: 15,000
# Trainable params: 15,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 [==============================] - 0s 46ms/step
# [[[ 0.02999168 -0.02259548 -0.01179771  0.02656499  0.01938977
#    -0.03006317 -0.02360096  0.01037411  0.03113519  0.01720287
#     0.0498308  -0.0125825  -0.04761681  0.0492186   0.04427192]
#   [-0.04560932 -0.00334371 -0.01395265 -0.03275166 -0.01777124
#     0.02782282 -0.02783812 -0.00328356 -0.01284833  0.01660879
#     0.03793989 -0.03457002 -0.03603528 -0.03037961  0.00369491]
#   [-0.04588087  0.0111514   0.04768812  0.02306905  0.04671755
#     0.0273739   0.03106156  0.01128999 -0.01775994 -0.03928405
#    -0.00901872  0.02912985  0.00634515 -0.03347228 -0.00901402]
#   [ 0.02604326  0.02824687 -0.03304516  0.02055771  0.00230653
#    -0.01543498 -0.00232007 -0.03658886 -0.0310101  -0.02898312
#    -0.04617188  0.01410283 -0.0077877   0.01368756 -0.02529585]
#   [-0.02024771  0.01061157  0.02446637  0.02961439  0.0148785
#    -0.01428081  0.02774559  0.01000997  0.03349514  0.02294638
# ...

# %%
embedded_docs[0]
# Out:
# array([397, 418, 679,   2,   0,   0,   0,   0,   0,   0], dtype=int32)

# %%
print(model.predict(embedded_docs)[0])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[ 0.02999168 -0.02259548 -0.01179771  0.02656499  0.01938977 -0.03006317
#   -0.02360096  0.01037411  0.03113519  0.01720287  0.0498308  -0.0125825
#   -0.04761681  0.0492186   0.04427192]
#  [-0.04560932 -0.00334371 -0.01395265 -0.03275166 -0.01777124  0.02782282
#   -0.02783812 -0.00328356 -0.01284833  0.01660879  0.03793989 -0.03457002
#   -0.03603528 -0.03037961  0.00369491]
#  [-0.04588087  0.0111514   0.04768812  0.02306905  0.04671755  0.0273739
#    0.03106156  0.01128999 -0.01775994 -0.03928405 -0.00901872  0.02912985
#    0.00634515 -0.03347228 -0.00901402]
#  [ 0.02604326  0.02824687 -0.03304516  0.02055771  0.00230653 -0.01543498
#   -0.00232007 -0.03658886 -0.0310101  -0.02898312 -0.04617188  0.01410283
#   -0.0077877   0.01368756 -0.02529585]
#  [-0.02024771  0.01061157  0.02446637  0.02961439  0.0148785  -0.01428081
#    0.02774559  0.01000997  0.03349514  0.02294638  0.03164986 -0.02642254
# ...
